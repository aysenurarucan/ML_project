# %%
# !pip install streamlit
import streamlit as st
import pandas as pd
import numpy as np
import joblib
from PIL import Image, ImageEnhance
import matplotlib.pyplot as plt
import seaborn as sns

def main():

    st.sidebar.title('Streamlit ile ml uygulaması')
   
        

def predict():
    urller = load_data()
    st.title('Merhaba, *Streamlit!')
    selected_brand = url_index(urller,st.selectbox('url seçiniz..',urller))
    selected_os = isletim_sistemi(st.radio("İşletim Sistemi",('Huawei İşletim Sistemi','Android')))
    
    
    selected_memory = st.number_input('Islemci_Tipi',min_value=0,max_value=6)
    st.write("Islemci_Tipi:"+str(selected_memory)+"GB")
    
    selected_front_cam = st.number_input('Cozunurluk',min_value=0,max_value=8)
    st.write("Cozunurluk:"+str(elected_front_cam)+"MP")
                                                              
    selected_back_cam = st.number_input('Bellek_Kapasitesi',min_value=0,max_value=3)
    st.write("Bellek_Kapasitesi:"+str(selected_back_cam)+"GB")        
            
        
            
    selected_model = st.selectbox('Tahmin modeli seçin..',["Decision Tree","Multple Lineer","Random Forest","Lasso","Ridge","Support Vector","Gradient Boosting"]) 
            
    prediction_value = create_prediction_value(selected_brand,selected_os,selected_memeory,selected_front_cam,selected_back_cam)
    prediction_model = load_models(selected_model)
    
    
    if st.button("Tahmin Yap"):
        result = predict_models(prediction_model,prediction_value)
        if result != None:
            st.success('Tahmin Başarılı')
            st.balloons()
            st.write("Tahmin edilen fiyat:"+ result +TL)
        else:
            st.error('Tahmin yaparken hata meydana geldi..!')

            
            
            
def load_data():
    urller = pd.read_excel('C:\\Users\\Dell\\OneDrive\\Masaüstü\\mlodev\\tablet5.xlsx')
    return urller
            
    
def load_models(modelName):
    if modelName == "Decion Tree":
        dt_model = joblib.load("C:\\Users\\Dell\\OneDrive\\Masaüstü\\mlodev\\desicion_tree_model.pkl")
        return dt_model

    elif modelName == "Multple Lineer":
        mlineer_model = joblib.load("C:\\Users\\Dell\\OneDrive\\Masaüstü\\mlodev\\multiple_linear_model.pkl")
        return mlinear_model

    elif modelName == "Random Forest":
        rf_model = joblib.load("C:\\Users\\Dell\\OneDrive\\Masaüstü\\mlodev\\random_forest_regression_model.pkl")
        return rf_model

    elif modelName == "Lasso":
        ls_model = joblib.load("C:\\Users\\Dell\\OneDrive\\Masaüstü\\mlodev\\lasso_regression_model.pkl")
        return ls_model

    elif modelName == "Ridge":
        rg_model = joblib.load("C:\\Users\\Dell\\OneDrive\\Masaüstü\\mlodev\\ridge_model.pkl")
        return rg_model

    elif modelName == "Support Vector":
        sv_model = joblib.load("C:\\Users\\Dell\\OneDrive\\Masaüstü\\mlodev\\svr_model.pkl")
        return sv_model

    elif modelName == "Gradient Boosting":
        gb_model = joblib.load("C:\\Users\\Dell\\OneDrive\\Masaüstü\\mlodev\\gradient_boosting_model.pkl")
        return gb_model
    
    else:
        st.write("Model yüklenirken hata meydana geldi..!")
        return 0


    
def url_index(urller,url):
    index = int(urrller[urller["urller"]==url].index.values)
    return index



def isletim_sistemi(isletim_sistemi):
    if isletim_sistemi == "Android":
        return 1
    else:
        return 0
    
    
    
def create_prediction_value(url,isletim_sistemi,islemci_tipi,cozunurluk,bellek_kapasitesi):
    res=pd.DataFrame(data={'url':[url],'isletim_sistemi':[isletim_sistemi],'islemci_tipi':[islemci_tipi],'cozunurluk':[cozunurluk],'bellek_kapasitesi':[bellek_kapasitesi]})
    return res


def predict_model(model,res):
    result = str(int(model.predict(res))).strip('[]')
    return result


if __name__ == "__main__":
    main()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
